# %%
import import_ipynb
import numpy as np 
import matplotlib.pyplot as plt 
from brownian_demo import wiener_process

# %% [markdown]
# $S_{t} = S_{o}\exp{(μ-\frac{σ}{2}+σW)}$

# %%
def gbm(n_steps = 252, T=1, n_paths = 5,mu = 0.1, sigma = 0.2,S0 = 100):
    '''Simulate Geometric Brownian Motion paths.
        param n_steps: Number of time steps
        param T: Total time
        param n_paths: Number of paths to simulate  
        param mu: Drift coefficient
        param sigma: Volatility coefficient
        param S0: Initial stock price
        return: Simulated GBM paths as a numpy array of shape (n_steps, n_paths)
        return: Time points corresponding to the simulated paths as a numpy array of shape (n_steps,)
    '''
    dt = T/n_steps
    t = np.arange(0, T, dt).reshape(n_steps,1)
    W,times = wiener_process(n_steps=n_steps, n_paths=n_paths)
    S = np.full(shape = n_paths, fill_value =S0).reshape(1,n_paths) * np.exp((mu - 0.5 * sigma**2) * t + sigma * W)
    return S, times

# %%
plt.figure(figsize=(10,6))
gbm_paths, times = gbm(n_paths=1)
for i in range(gbm_paths.shape[1]):
    plt.plot(times, gbm_paths[:, i], label=f'Path {i+1}')
plt.title('Simulated Geometric Brownian Motion Paths')
plt.xlabel('Time')
plt.ylabel('Stock Price')
plt.legend()
plt.grid()
plt.show()

# %%
S,t = gbm(n_steps=252,n_paths= 1)
print(S.shape)
# Out:
# (252, 1)

# %%
np.full(shape = 1, fill_value =100).reshape(1,1)
# Out:
# (1, 1)

# %%
n_paths = 1
S0=100
n_steps=252
T = 1
dt = T/n_steps
t = np.arange(0, T, dt).reshape(n_steps,n_paths)
mu = 0.1
sigma = 0.2
W,times = wiener_process(n_steps=n_steps, n_paths=n_paths)
np.full(shape = n_paths, fill_value =S0).reshape(1,n_paths) * np.exp((mu - 0.5 * sigma**2) * t + sigma * W)
# Out:
# (252, 1)

# %%
gbm(n_paths=7)[0][:,0].shape
# Out:
# (252,)

# %%
np.exp((mu - 0.5 * sigma**2) * t + sigma * W).shape
# Out:
# (252, 252)

# %%
sigma * W
# Out:
# array([[ 0.00625801],
#        [ 0.00451604],
#        [ 0.01267615],
#        [ 0.03186452],
#        [ 0.02891447],
#        [ 0.02596462],
#        [ 0.04586083],
#        [ 0.0555296 ],
#        [ 0.04961478],
#        [ 0.05645039],
#        [ 0.05061188],
#        [ 0.04474424],
#        [ 0.04779267],
#        [ 0.02368761],
#        [ 0.00195569],
#        [-0.00512847],
#        [-0.01788894],
#        [-0.0139298 ],
#        [-0.02536983],
#        [-0.04316318],
#        [-0.02469774],
#        [-0.02754226],
#        [-0.02669148],
#        [-0.04464162],
#        [-0.0515002 ],
#        [-0.0501027 ],
#        [-0.06460386],
#        [-0.05987051],
#        [-0.06743785],
#        [-0.07111284],
#        [-0.07869363],
#        [-0.05535712],
#        [-0.05552717],
#        [-0.06885308],
#        [-0.14454414],
#        [-0.13627234],
#        [-0.14855217],
#        [-0.13863584],
#        [-0.12403891],
#        [-0.13437853],
#        [-0.12224113],
#        [-0.11704058],
#        [-0.1066836 ],
#        [-0.08278625],
#        [-0.08587785],
#        [-0.09537403],
#        [-0.10658086],
#        [-0.11685911],
#        [-0.1178305 ],
#        [-0.11353239],
#        [-0.11004641],
#        [-0.09962488],
#        [-0.09946107],
#        [-0.08114826],
#        [-0.08448263],
#        [-0.05021172],
#        [-0.04232905],
#        [-0.05312822],
#        [-0.0666202 ],
#        [-0.06054161],
#        [-0.06335698],
#        [-0.05436142],
#        [-0.04839919],
#        [-0.04931675],
#        [-0.05998534],
#        [-0.07907062],
#        [-0.08469618],
#        [-0.07390657],
#        [-0.07120925],
#        [-0.08690408],
#        [-0.0847222 ],
#        [-0.07986766],
#        [-0.09100322],
#        [-0.08906646],
#        [-0.0883331 ],
#        [-0.10273318],
#        [-0.09822548],
#        [-0.09116026],
#        [-0.07751509],
#        [-0.06423844],
#        [-0.08159544],
#        [-0.09341092],
#        [-0.08692209],
#        [-0.080449  ],
#        [-0.07396   ],
#        [-0.02542015],
#        [-0.01822761],
#        [-0.00392082],
#        [ 0.00809847],
#        [ 0.01630523],
#        [ 0.01233321],
#        [ 0.02189532],
#        [ 0.01215864],
#        [ 0.00917501],
#        [ 0.00306   ],
#        [ 0.00409152],
#        [ 0.03325347],
#        [ 0.00972814],
#        [ 0.01837421],
#        [-0.0019441 ],
#        [-0.00788988],
#        [ 0.0058296 ],
#        [ 0.00663946],
#        [-0.00693885],
#        [-0.01595083],
#        [-0.0073887 ],
#        [-0.01659046],
#        [-0.01386334],
#        [-0.01328919],
#        [-0.02149858],
#        [ 0.00551258],
#        [ 0.01349921],
#        [-0.01201519],
#        [-0.00966609],
#        [-0.01800381],
#        [-0.00726416],
#        [-0.01724899],
#        [-0.01869453],
#        [-0.01233229],
#        [-0.0014248 ],
#        [-0.01654711],
#        [-0.02076143],
#        [-0.02674518],
#        [-0.03497635],
#        [-0.01273372],
#        [-0.00763143],
#        [-0.02351708],
#        [-0.0119531 ]])

# %%
W.shape
# Out:
# (252, 1)

# %%
((mu - 0.5 * sigma**2) * t + sigma * W).shape
# Out:
# (252, 1)

# %%
n_paths = 1
t = t.reshape(n_steps,n_paths)
t.shape
# Out:
# (252, 1)

# %%
(t+W).shape
# Out:
# (252, 252)

# %%
(sigma * W).shape
# Out:
# (252, 1)

# %%
np.arange(0, T, dt).shape
# Out:
# (252,)

# %%
((mu - 0.5 * sigma**2) * t).shape
# Out:
# (252, 1)

# %%
np.full(shape = n_paths, fill_value =20).reshape(1,n_paths).shape
# Out:
# (1, 1)

# %%
t.shape
# Out:
# (252,)
