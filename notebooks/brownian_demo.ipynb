# %% [markdown]
# A standard Brownian motion \(W_{t}\) has \(W_{0}=0\), independent increments \(W_{t}-W_{s}\sim N(0,t-s)\) for \(0\le s<t\), and continuous paths.

# %% [markdown]
# $L = \frac{1}{n}\sum_{i=1}^n (y_i - \hat{y}_i)^2$.

# %% [markdown]
# ($W_{t}$)
